# %% [markdown]
# ## Importing all csvs

# %%
# !unzip '/content/A_NEWLY_HIRED_DATA_ANALYST (1).zip' -d '/content/'

# %%
import pandas as pd
import glob

glob.glob('/content/A_NEWLY_HIRED_DATA_ANALYST/*.csv')
# Out:
# ['/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_97_99.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_16_20.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_16_20.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_97_99.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_11_15.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_11_15.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_11_15.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_16_20.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_97_99.csv']

# %%
all_2NAICS = glob.glob('/content/A_NEWLY_HIRED_DATA_ANALYST/*2NAICS*')
all_2NAICS
# Out:
# ['/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_16_20.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_11_15.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_2NAICS_97_99.csv']

# %%
all_3NAICS = glob.glob('/content/A_NEWLY_HIRED_DATA_ANALYST/*3NAICS*')
all_3NAICS
# Out:
# ['/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_97_99.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_11_15.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_3NAICS_16_20.csv']

# %%
all_4NAICS = glob.glob('/content/A_NEWLY_HIRED_DATA_ANALYST/*4NAICS*')
all_4NAICS
# Out:
# ['/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_06_10.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_16_20.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_00_05.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_97_99.csv',
#  '/content/A_NEWLY_HIRED_DATA_ANALYST/RTRA_Employ_4NAICS_11_15.csv']

# %%
def get_datasets(data_paths):
    df = pd.DataFrame()
    for path_ in data_paths:
        df = pd.concat([df,pd.read_csv(path_)])
    return df

# %%
## Reading all Naics datasets and their three types respectively
data_2NAICS = get_datasets(all_2NAICS)
data_3NAICS = get_datasets(all_3NAICS)
data_4NAICS = get_datasets(all_4NAICS)

# %%
data_2NAICS
# Out:
#      SYEAR  ...  _EMPLOYMENT_
# 0     2000  ...        148000
# 1     2000  ...         59250
# 2     2000  ...         61750
# 3     2000  ...         39500
# 4     2000  ...        106250
# ..     ...  ...           ...
# 715   1999  ...         37000
# 716   1999  ...        230750
# 717   1999  ...        117500
# 718   1999  ...         10250
# 719   1999  ...         74000
#
# [5472 rows x 4 columns]

# %%
def data_format(df):
  df['date'] = pd.to_datetime(df.SYEAR.astype('str') + df.SMTH.astype('str'), format='%Y%m')
  df= df.drop(columns=['SYEAR','SMTH'])
  df2 = df.sort_values('date')
  return df2

# %%
data_2NAICS = data_format(data_2NAICS)
data_2NAICS
# Out:
#                                                  NAICS  _EMPLOYMENT_       date
# 19                               Wholesale trade  [41]         72000 1997-01-01
# 18                                      Utilities [22]          9750 1997-01-01
# 17              Transportation and warehousing [48-49]        107000 1997-01-01
# 16                               Retail trade  [44-45]        224000 1997-01-01
# 15                Real estate, rental and leasing [53]         50750 1997-01-01
# ..                                                 ...           ...        ...
# 895    Agriculture, forestry, fishing and hunting [11]             0 2019-12-01
# 894  Administrative and support, waste management a...             0 2019-12-01
# 893               Accommodation and food services [72]             0 2019-12-01
# 903  Mining, quarrying, and oil and gas extraction ...             0 2019-12-01
# 898                          Educational services [61]             0 2019-12-01
#
# [5472 rows x 3 columns]

# %%
data_3NAICS = data_format(data_3NAICS)
data_4NAICS = data_format(data_4NAICS)

# %%
data_3NAICS
# Out:
#                                                   NAICS  ...       date
# 75                              Private households[814]  ... 1997-01-01
# 76    Professional, scientific and technical service...  ... 1997-01-01
# 74         Printing and related support activities[323]  ... 1997-01-01
# 73                     Primary metal manufacturing[331]  ... 1997-01-01
# 72                                  Postal service[491]  ... 1997-01-01
# ...                                                 ...  ...        ...
# 4775                      Food and beverage stores[445]  ... 2019-12-01
# 4774                 Fishing, hunting and trapping[114]  ... 2019-12-01
# 4773      Federal government public administration[911]  ... 2019-12-01
# 4783                             Gasoline stations[447]  ... 2019-12-01
# 4847                    Wood product manufacturing[321]  ... 2019-12-01
#
# [28140 rows x 3 columns]

# %%
data_4NAICS
# Out:
#        NAICS  _EMPLOYMENT_       date
# 230     5322          8250 1997-01-01
# 210     5171         11000 1997-01-01
# 209     5151          4750 1997-01-01
# 208     5122           500 1997-01-01
# 207     5121          6000 1997-01-01
# ...      ...           ...        ...
# 14574   3336             0 2019-12-01
# 14573   3335             0 2019-12-01
# 14572   3334             0 2019-12-01
# 14579   3344             0 2019-12-01
# 14782   9141             0 2019-12-01
#
# [85572 rows x 3 columns]

# %%
## Let's compare the three types; 2Naics, 3, and 4 from the employment point of view:

comparison = pd.DataFrame({'2digit_data':data_2NAICS.groupby('date')['_EMPLOYMENT_'].sum(),
              '3digit_data':data_3NAICS.groupby('date')['_EMPLOYMENT_'].sum(),
              '4digit_data':data_4NAICS.groupby('date')['_EMPLOYMENT_'].sum()})
comparison['2 - 3'] = comparison['2digit_data'] - comparison['3digit_data']
comparison['2 - 4'] = comparison['2digit_data'] - comparison['4digit_data'] 
comparison['3 - 4'] = comparison['3digit_data'] - comparison['4digit_data']  
comparison
# Out:
#             2digit_data  3digit_data  4digit_data  2 - 3  2 - 4  3 - 4
# date
# 1997-01-01      1802250      1802250      1802500      0   -250   -250
# 1997-02-01      1808000      1808000      1808250      0   -250   -250
# 1997-03-01      1815250      1815250      1815500      0   -250   -250
# 1997-04-01      1827750      1827750      1827500      0    250    250
# 1997-05-01      1864500      1864750      1864750   -250   -250      0
# ...                 ...          ...          ...    ...    ...    ...
# 2019-08-01      2580750      2580500      2580750    250      0   -250
# 2019-09-01      2558750      2558750      2558500      0    250    250
# 2019-10-01            0            0            0      0      0      0
# 2019-11-01            0            0            0      0      0      0
# 2019-12-01            0            0            0      0      0      0
#
# [276 rows x 6 columns]

# %%
comparison['2 - 3'].sum()
# Out:
# 0

# %%
comparison['3 - 4'].sum()
# Out:
# 250

# %%
comparison['2 - 4'].sum()
# Out:
# 250

# %%
## Let's take the fourth Naics dataset as our study case

# %%
 ## Let's have the four-digit aggreagation level, and begin to studying it:

data_4NAICS['NAICS'] = data_4NAICS['NAICS'].astype('str')
data_4NAICS.set_index('date', inplace=True)

# %%
## as clear, data series starts for 1997, ends at 2019..
data_4NAICS
# Out:
#            NAICS  _EMPLOYMENT_
# date
# 1997-01-01  5322          8250
# 1997-01-01  5171         11000
# 1997-01-01  5151          4750
# 1997-01-01  5122           500
# 1997-01-01  5121          6000
# ...          ...           ...
# 2019-12-01  3336             0
# 2019-12-01  3335             0
# 2019-12-01  3334             0
# 2019-12-01  3344             0
# 2019-12-01  9141             0
#
# [85572 rows x 2 columns]

# %%
## let's do the same for output data:
df_out = pd.read_excel('/content/A_NEWLY_HIRED_DATA_ANALYST/Data_Output_Template.xlsx')

# %%
df_out= data_format(df_out)
df_out
# Out:
#                                    LMO_Detailed_Industry  Employment       date
# 0                                 Accommodation services         NaN 1997-01-01
# 32                                   Other manufacturing         NaN 1997-01-01
# 33     Other retail trade (excluding cars and persona...         NaN 1997-01-01
# 34                                   Paper manufacturing         NaN 1997-01-01
# 35     Performing arts, spectator sports and related ...         NaN 1997-01-01
# ...                                                  ...         ...        ...
# 15541         Local and Indigenous public administration         NaN 2018-12-01
# 15542                            Machinery manufacturing         NaN 2018-12-01
# 15543  Management, scientific and technical consultin...         NaN 2018-12-01
# 15545      Motion picture and sound recording industries         NaN 2018-12-01
# 15575                         Wood product manufacturing         NaN 2018-12-01
#
# [15576 rows x 3 columns]

# %%
df_out['LMO_Detailed_Industry'] = df_out['LMO_Detailed_Industry'].astype('str')
df_out.set_index('date', inplace=True)

# %%
df_out.head()
# Out:
#                                         LMO_Detailed_Industry  Employment
# date
# 1997-01-01                             Accommodation services         NaN
# 1997-01-01                                Other manufacturing         NaN
# 1997-01-01  Other retail trade (excluding cars and persona...         NaN
# 1997-01-01                                Paper manufacturing         NaN
# 1997-01-01  Performing arts, spectator sports and related ...         NaN

# %%
data_4NAICS
# Out:
#            NAICS  _EMPLOYMENT_
# date
# 1997-01-01  5322          8250
# 1997-01-01  5171         11000
# 1997-01-01  5151          4750
# 1997-01-01  5122           500
# 1997-01-01  5121          6000
# ...          ...           ...
# 2019-12-01  3336             0
# 2019-12-01  3335             0
# 2019-12-01  3334             0
# 2019-12-01  3344             0
# 2019-12-01  9141             0
#
# [85572 rows x 2 columns]

# %%
## Let's decode industry names now in digit-four so we can have our output:

industries = pd.read_excel('/content/LMO_Detailed_Industries_by_NAICS.xlsx')

industries['NAICS'] = industries['NAICS'].replace(regex='&', value=',')
industries['NAICS'] = industries['NAICS'].astype('str')
industries
# Out:
#                                 LMO_Detailed_Industry                                              NAICS
# 0                                               Farms                                          111 , 112
# 1                       Fishing, hunting and trapping                                                114
# 2                                Forestry and logging                                                113
# 3     Support activities for agriculture and forestry                                                115
# 4                              Oil and gas extraction                                                211
# 5   Support activities for mining and oil and gas ...                                                213
# 6                                              Mining                                                212
# 7                                           Utilities                                                 22
# 8                                        Construction                                                 23
# 9            Food, beverage and tobacco manufacturing                                          311 , 312
# 10                         Wood product manufacturing                                                321
# 11                                Paper manufacturing                                                322
# 12                        Primary metal manufacturing                                                331
# 13             Fabricated metal product manufacturing                                                332
# 14                            Machinery manufacturing                                                333
# 15                             Ship and boat building                                               3366
# 16  Transportation equipment manufacturing (exclud...               3361,  3362,  3363, 3364, 3365, 3369
# 17                                Other manufacturing  313, 314, 315, 316, 323, 324, 325, 326, 327, 3...
# 18                                    Wholesale trade                                                 41
# 19                    Motor vehicle and parts dealers                                                441
# 20                    Health and personal care stores                                                446
# 21  Other retail trade (excluding cars and persona...      442,443,444,445,446,447,448,451,452,453 , 454
# 22                                 Air transportation                                                481
# 23                                Rail transportation                                                482
# 24                               Water transportation                                                483
# 25                               Truck transportation                                                484
# 26              Support activities for transportation                                                488
# 27            Postal service, couriers and messengers                                          491 , 492
# 28  Transit, sightseeing, and pipeline transportation                                      485,486 , 487
# 29                            Warehousing and storage                                                493
# 30          Insurance carriers and related activities                                                524
# 31                                            Finance                                521, 522, 523 , 526
# 32                     Real estate rental and leasing                                                 53
# 33    Architectural, engineering and related services                                               5413
# 34       Computer systems design and related services                                               5415
# 35  Management, scientific and technical consultin...                                               5416
# 36  Legal, accounting, design, research, and adver...                5411, 5412, 5414, 5417, 5418 , 5419
# 37      Business, building and other support services                                            55 , 56
# 38                   Elementary and secondary schools                                               6111
# 39                                 Community colleges                                               6112
# 40                                       Universities                                               6113
# 41                       Private and trades education                            6114, 6115, 6116 , 6117
# 42                    Ambulatory health care services                                                621
# 43                                          Hospitals                                                622
# 44            Nursing and residential care facilities                                                623
# 45                                  Social assistance                                                624
# 46                              Publishing industries                                                511
# 47      Motion picture and sound recording industries                                                512
# 48                                 Telecommunications                                                517
# 49     Broadcasting, data processing, and information                                     515, 518 , 519
# 50  Performing arts, spectator sports and related ...                                                711
# 51      Amusement, gambling and recreation industries                                                713
# 52                              Heritage institutions                                                712
# 53                             Accommodation services                                                721
# 54                  Food services and drinking places                                                722
# 55           Repair, personal and non-profit services                                                 81
# 56           Federal government public administration                                                911
# 57   Provincial and territorial public administration                                                912
# 58         Local and Indigenous public administration                                     913, 914 , 919

# %%
## Create a dictionary for every value, their corresponding name, and their corresponding num-figits:

industries_dictionary = {
    'two_digits' : {}, 
    'three_digits' : {}, 
    'four_digits' : {}
}
for name, numbers in zip(industries['LMO_Detailed_Industry'].values, industries['NAICS'].values):
    num_list = numbers.split(',')
    num_list = [x.strip() for x in num_list]
    for i in range(len(num_list)):
        if len(num_list[i]) == 2:
            industries_dictionary['two_digits'][num_list[i]] = name
        elif len(num_list[i]) == 3:
            industries_dictionary['three_digits'][num_list[i]] = name 
        elif len(num_list[i]) == 4:
            industries_dictionary['four_digits'][num_list[i]] = name

# %%
industries_dictionary
# Out:
# {'four_digits': {'3361': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '3362': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '3363': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '3364': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '3365': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '3366': 'Ship and boat building',
#   '3369': 'Transportation equipment manufacturing (excluding shipbuilding)',
#   '5411': 'Legal, accounting, design, research, and advertising services',
#   '5412': 'Legal, accounting, design, research, and advertising services',
#   '5413': 'Architectural, engineering and related services',
#   '5414': 'Legal, accounting, design, research, and advertising services',
#   '5415': 'Computer systems design and related services',
#   '5416': 'Management, scientific and technical consulting services',
#   '5417': 'Legal, accounting, design, research, and advertising services',
#   '5418': 'Legal, accounting, design, research, and advertising services',
#   '5419': 'Legal, accounting, design, research, and advertising services',
#   '6111': 'Elementary and secondary schools',
#   '6112': 'Community colleges',
#   '6113': 'Universities',
#   '6114': 'Private and trades education',
#   '6115': 'Private and trades education',
#   '6116': 'Private and trades education',
#   '6117': 'Private and trades education'},
#  'three_digits': {'111': 'Farms',
#   '112': 'Farms',
#   '113': 'Forestry and logging',
#   '114': 'Fishing, hunting and trapping',
#   '115': 'Support activities for agriculture and forestry',
#   '211': 'Oil and gas extraction',
#   '212': 'Mining',
#   '213': 'Support activities for mining and oil and gas extraction',
#   '311': 'Food, beverage and tobacco manufacturing',
#   '312': 'Food, beverage and tobacco manufacturing',
#   '313': 'Other manufacturing',
#   '314': 'Other manufacturing',
#   '315': 'Other manufacturing',
#   '316': 'Other manufacturing',
#   '321': 'Wood product manufacturing',
#   '322': 'Paper manufacturing',
#   '323': 'Other manufacturing',
#   '324': 'Other manufacturing',
#   '325': 'Other manufacturing',
#   '326': 'Other manufacturing',
#   '327': 'Other manufacturing',
#   '331': 'Primary metal manufacturing',
#   '332': 'Fabricated metal product manufacturing',
#   '333': 'Machinery manufacturing',
#   '334': 'Other manufacturing',
#   '335': 'Other manufacturing',
#   '337': 'Other manufacturing',
#   '339': 'Other manufacturing',
#   '441': 'Motor vehicle and parts dealers',
#   '442': 'Other retail trade (excluding cars and personal care) ',
#   '443': 'Other retail trade (excluding cars and personal care) ',
#   '444': 'Other retail trade (excluding cars and personal care) ',
#   '445': 'Other retail trade (excluding cars and personal care) ',
#   '446': 'Other retail trade (excluding cars and personal care) ',
#   '447': 'Other retail trade (excluding cars and personal care) ',
#   '448': 'Other retail trade (excluding cars and personal care) ',
#   '451': 'Other retail trade (excluding cars and personal care) ',
#   '452': 'Other retail trade (excluding cars and personal care) ',
#   '453': 'Other retail trade (excluding cars and personal care) ',
#   '454': 'Other retail trade (excluding cars and personal care) ',
#   '481': 'Air transportation',
#   '482': 'Rail transportation',
#   '483': 'Water transportation',
#   '484': 'Truck transportation',
#   '485': 'Transit, sightseeing, and pipeline transportation',
#   '486': 'Transit, sightseeing, and pipeline transportation',
#   '487': 'Transit, sightseeing, and pipeline transportation',
#   '488': 'Support activities for transportation',
#   '491': 'Postal service, couriers and messengers',
#   '492': 'Postal service, couriers and messengers',
#   '493': 'Warehousing and storage',
#   '511': 'Publishing industries',
#   '512': 'Motion picture and sound recording industries',
#   '515': 'Broadcasting, data processing, and information',
#   '517': 'Telecommunications',
#   '518': 'Broadcasting, data processing, and information',
#   '519': 'Broadcasting, data processing, and information',
#   '521': 'Finance',
#   '522': 'Finance',
#   '523': 'Finance',
#   '524': 'Insurance carriers and related activities',
#   '526': 'Finance',
#   '621': 'Ambulatory health care services',
#   '622': 'Hospitals',
#   '623': 'Nursing and residential care facilities',
#   '624': 'Social assistance',
#   '711': 'Performing arts, spectator sports and related industries',
#   '712': 'Heritage institutions',
#   '713': 'Amusement, gambling and recreation industries',
#   '721': 'Accommodation services',
#   '722': 'Food services and drinking places',
#   '911': 'Federal government public administration',
#   '912': 'Provincial and territorial public administration',
#   '913': 'Local and Indigenous public administration',
#   '914': 'Local and Indigenous public administration',
#   '919': 'Local and Indigenous public administration'},
#  'two_digits': {'22': 'Utilities',
#   '23': 'Construction',
#   '41': 'Wholesale trade',
#   '53': 'Real estate rental and leasing',
#   '55': 'Business, building and other support services',
#   '56': 'Business, building and other support services',
#   '81': 'Repair, personal and non-profit services'}}

# %%
## Let's use the dictionary for decoding
import numpy as np

industry_decoded = [] 
for code in data_4NAICS['NAICS']:
    if code[:2] in industries_dictionary['two_digits'].keys():
        industry_decoded.append(industries_dictionary['two_digits'][code[:2]])
    elif code[:3] in industries_dictionary['three_digits'].keys():
        industry_decoded.append(industries_dictionary['three_digits'][code[:3]])
    elif code in industries_dictionary['four_digits'].keys(): 
        industry_decoded.append(industries_dictionary['four_digits'][code])
    else:
        industry_decoded.append(np.nan)

# %%
## now everything is ready to create the decoded column:
data_4NAICS['industry_name'] = industry_decoded
print('Undecoded industry name')
print(data_4NAICS[data_4NAICS['industry_name'].isna()]['NAICS'].unique())
print(data_4NAICS[data_4NAICS['industry_name'].isna()]['NAICS'].value_counts())
print('Total Employment with no clear industry')
print(data_4NAICS[data_4NAICS['industry_name'].isna()]['_EMPLOYMENT_'].sum())
print('Total Employment with a clear industry')
print(data_4NAICS[data_4NAICS['industry_name'].notna()]['_EMPLOYMENT_'].sum())
# Out:
# Undecoded industry name
# ['1100' '2100']
# 1100    276
# 2100    276
# Name: NAICS, dtype: int64
# Total Employment with no clear industry
# 725000
# Total Employment with a clear industry
# 588918000

# %%
## Total number of employment with no clear industry can be ignored with no problems..

### Now let's inspect number of employees we will have to drop at each year 
pd.DataFrame({"Employment Numbers to drop":data_4NAICS[data_4NAICS.isna()['industry_name']].resample('Y')['_EMPLOYMENT_'].sum(),
              "Employment Numbers to left":data_4NAICS[data_4NAICS.notna()['industry_name']].resample('Y')['_EMPLOYMENT_'].sum()})
# Out:
#             Employment Numbers to drop  Employment Numbers to left
# date
# 1997-12-31                       40000                    22278750
# 1998-12-31                       27500                    22264750
# 1999-12-31                       15500                    22708500
# 2000-12-31                       32250                    23137000
# 2001-12-31                       21000                    23030000
# 2002-12-31                       17750                    23411500
# 2003-12-31                       27250                    23949750
# 2004-12-31                       21500                    24317750
# 2005-12-31                       46500                    25030000
# 2006-12-31                       38500                    25651750
# 2007-12-31                       57500                    26414000
# 2008-12-31                       23500                    26878750
# 2009-12-31                       21000                    26282500
# 2010-12-31                       30500                    26646000
# 2011-12-31                       34500                    26699000
# 2012-12-31                       44000                    27106000
# 2013-12-31                       44500                    27142250
# 2014-12-31                       25500                    27315500
# 2015-12-31                       18000                    27656750
# 2016-12-31                       16500                    28537500
# 2017-12-31                       52500                    29548750
# 2018-12-31                       42500                    29880750
# 2019-12-31                       26750                    23030500

# %%
## let's get rid of any useless data parts, dropping encoded industry values, and renaming employment..
data_4NAICS.rename(columns={'_EMPLOYMENT_':'employment'}, inplace=True)
data_4NAICS.drop(columns=['NAICS'], inplace=True)
data_4NAICS.head()
# Out:
#             employment                                   industry_name
# date
# 1997-01-01        8250                  Real estate rental and leasing
# 1997-01-01       11000                              Telecommunications
# 1997-01-01        4750  Broadcasting, data processing, and information
# 1997-01-01         500   Motion picture and sound recording industries
# 1997-01-01        6000   Motion picture and sound recording industries

# %%
data_4NAICS
# Out:
#             employment                                   industry_name
# date
# 1997-01-01        8250                  Real estate rental and leasing
# 1997-01-01       11000                              Telecommunications
# 1997-01-01        4750  Broadcasting, data processing, and information
# 1997-01-01         500   Motion picture and sound recording industries
# 1997-01-01        6000   Motion picture and sound recording industries
# ...                ...                                             ...
# 2019-12-01           0                         Machinery manufacturing
# 2019-12-01           0                         Machinery manufacturing
# 2019-12-01           0                         Machinery manufacturing
# 2019-12-01           0                             Other manufacturing
# 2019-12-01           0      Local and Indigenous public administration
#
# [85572 rows x 2 columns]

# %%
df_out.columns = ['industry_name','employment']

# %%
DF_OUTPUT= df_out.merge(data_4NAICS,left_on=['date','industry_name'], 
right_on=['date','industry_name'], how='left')
DF_OUTPUT
# Out:
#                                             industry_name  ...  employment_y
# date                                                       ...
# 1997-01-01                         Accommodation services  ...           0.0
# 1997-01-01                         Accommodation services  ...        1750.0
# 1997-01-01                         Accommodation services  ...       22500.0
# 1997-01-01                            Other manufacturing  ...           0.0
# 1997-01-01                            Other manufacturing  ...         750.0
# ...                                                   ...  ...           ...
# 2018-12-01  Motion picture and sound recording industries  ...        1750.0
# 2018-12-01  Motion picture and sound recording industries  ...       18250.0
# 2018-12-01                     Wood product manufacturing  ...        5750.0
# 2018-12-01                     Wood product manufacturing  ...        2750.0
# 2018-12-01                     Wood product manufacturing  ...       15750.0
#
# [81612 rows x 3 columns]

# %%
DF_OUTPUT = DF_OUTPUT[['industry_name','employment_y']]
DF_OUTPUT.head(5)
# Out:
#                      industry_name  employment_y
# date
# 1997-01-01  Accommodation services           0.0
# 1997-01-01  Accommodation services        1750.0
# 1997-01-01  Accommodation services       22500.0
# 1997-01-01     Other manufacturing           0.0
# 1997-01-01     Other manufacturing         750.0

# %%
DF_OUTPUT.columns = ['LMO_Detailed_Industry','Employment']

# %%
DF_OUTPUT
# Out:
#                                     LMO_Detailed_Industry  Employment
# date
# 1997-01-01                         Accommodation services         0.0
# 1997-01-01                         Accommodation services      1750.0
# 1997-01-01                         Accommodation services     22500.0
# 1997-01-01                            Other manufacturing         0.0
# 1997-01-01                            Other manufacturing       750.0
# ...                                                   ...         ...
# 2018-12-01  Motion picture and sound recording industries      1750.0
# 2018-12-01  Motion picture and sound recording industries     18250.0
# 2018-12-01                     Wood product manufacturing      5750.0
# 2018-12-01                     Wood product manufacturing      2750.0
# 2018-12-01                     Wood product manufacturing     15750.0
#
# [81612 rows x 2 columns]

# %%
DF_OUTPUT.to_excel('data_out_results.xlsx')

# %%
## let's group each industry on its own to hold a good comparison throughout the cummulative of the years..
import matplotlib.pyplot as plt
import seaborn as sns

total_counts = data_4NAICS.groupby('industry_name')['employment'].sum().sort_values(ascending=False)
total_df = pd.DataFrame({'Industry':total_counts.index, 'Employments':total_counts.values})
plt.figure(figsize=(7,17))
sns.barplot(x='Employments', y='Industry', data = total_df,palette='mako');

# %%
## let's group data by industry names and dates to plot the evolution through years..

df = pd.DataFrame(data_4NAICS.reset_index().groupby(['date', 'industry_name'], as_index=False)['employment'].sum())

# %%
df = df.pivot('date', 'industry_name', 'employment')
df['total'] = df.sum(axis=1)
df = df.iloc[:-3]
df.index.freq = 'MS'

# %%
df.plot(subplots=True, figsize=(10, 120));

# %% [markdown]
# ## How wood production evolved in comparison with other industries

# %%
df['Wood product manufacturing'].plot(figsize=(12,5), title='Wood manufacturing')

# %%
df['total'].plot(figsize=(12,5), title='total')

# %%
df['Wood product manufacturing'].diff().plot(figsize=(12,5), title='1 Derivation of wood production')

# %% [markdown]
# ## How construction evolved in comparison with other industries

# %%
df['Construction'].plot(figsize=(12,5), title='Construction')

# %%
df['total'].plot(figsize=(12,5), title='total')

# %%
df['Construction'].diff().plot(figsize=(12,5), title='1 Derivation of construction')

# %% [markdown]
# ## How private education evolved in comparison with rail transportation
# as they sometimes correlate, we try to study them together

# %%
df['Private and trades education'].plot(figsize=(12,5), title='education')

# %%
df['Rail transportation'].plot(figsize=(12,5), title='transportation')

# %% [markdown]
# ## How wood production evolved in comparison with truck transportation

# %%
df['Wood product manufacturing'].plot(figsize=(12,5), title='Wood manufacturing')

# %%
df['Paper manufacturing'].plot(figsize=(12,5), title='Paper')

# %% [markdown]
# ## How does Air transportation change throughout the 25 years

# %%
df['Air transportation'].plot(figsize=(12,5), title='Air transportation')

# %%
df['Air transportation'].diff().plot(figsize=(12,5), title='1 Derivation of Air transportation')
